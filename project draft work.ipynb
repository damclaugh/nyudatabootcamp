# %%
# import packages 
import pandas as pd
import matplotlib as mpl 
import matplotlib.pyplot as plt
import numpy as np
import plotly
import plotly.plotly as py
import plotly.graph_objs as go

# IPython command, puts plots in notebook 
# %matplotlib inline

# %%
dftest = pd.read_excel('/Users/davidmclaughlin/Documents/Data_Bootcamp/census1114.xlsx')

# %%
dftest
# Out:
#                    Age   Total  Total Pct  Native  Native Pct Naturalized  \
# 0        .0 to 4 years  19,865        6.3  19,596         7.2          80
# 1        .5 to 9 years  20,522        6.5  19,914         7.3         189
# 2      .10 to 14 years  20,642        6.6  19,789         7.3         262
# 3      .15 to 19 years  20,807        6.6  19,337         7.1         415
# 4      .20 to 24 years  22,278        7.1  19,981         7.3         584
# 5      .25 to 29 years  21,474        6.9  18,102         6.6         874
# 6      .30 to 34 years  20,974        6.7  16,791         6.2       1,277
# 7      .35 to 39 years  19,407        6.2  14,947         5.5       1,526
# 8      .40 to 44 years  20,382        6.5  15,831         5.8       2,018
# 9      .45 to 49 years  20,668        6.6  16,538         6.1       2,219
# 10     .50 to 54 years  22,355        7.1  18,663         6.8       2,111
# 11     .55 to 59 years  21,109        6.7  18,055         6.6       1,966
# ...

# %%
type(dftest)
# Out:
# pandas.core.frame.DataFrame

# %%
dftest2 = pd.read_excel('/Users/davidmclaughlin/Documents/Data_Bootcamp/census1113.xlsx')

# %%
dftest2
# Out:
#                    Age   Total  Total Pct  Native  Native Pct Naturalized  \
# 0        .0 to 4 years  19,917        6.4  19,686         7.3          74
# 1        .5 to 9 years  20,536        6.6  20,027         7.4         134
# 2      .10 to 14 years  20,640        6.6  19,792         7.3         198
# 3      .15 to 19 years  20,970        6.7  19,512         7.2         377
# 4      .20 to 24 years  22,153        7.1  19,556         7.2         707
# 5      .25 to 29 years  21,138        6.8  17,555         6.5         977
# 6      .30 to 34 years  20,659        6.6  16,510         6.1       1,212
# 7      .35 to 39 years  19,221        6.2  14,745         5.4       1,482
# 8      .40 to 44 years  20,657        6.6  16,365         6.0       1,882
# 9      .45 to 49 years  21,060        6.8  17,015         6.3       2,057
# 10     .50 to 54 years  22,386        7.2  18,781         6.9       1,994
# 11     .55 to 59 years  20,880        6.7  18,055         6.7       1,703
# ...

# %%
dftest.insert(0, 'Year', '2014')
dftest
# Out:
#     Year                 Age   Total  Total Pct  Native  Native Pct  \
# 0   2014       .0 to 4 years  19,865        6.3  19,596         7.2
# 1   2014       .5 to 9 years  20,522        6.5  19,914         7.3
# 2   2014     .10 to 14 years  20,642        6.6  19,789         7.3
# 3   2014     .15 to 19 years  20,807        6.6  19,337         7.1
# 4   2014     .20 to 24 years  22,278        7.1  19,981         7.3
# 5   2014     .25 to 29 years  21,474        6.9  18,102         6.6
# 6   2014     .30 to 34 years  20,974        6.7  16,791         6.2
# 7   2014     .35 to 39 years  19,407        6.2  14,947         5.5
# 8   2014     .40 to 44 years  20,382        6.5  15,831         5.8
# 9   2014     .45 to 49 years  20,668        6.6  16,538         6.1
# 10  2014     .50 to 54 years  22,355        7.1  18,663         6.8
# 11  2014     .55 to 59 years  21,109        6.7  18,055         6.6
# 12  2014     .60 to 64 years  18,440        5.9  16,007         5.9
# ...

# %%
dftest.iloc[15:]
# Out:
#     Year                 Age  Total  Total Pct Native  Native Pct Naturalized  \
# 15  2014     .75 to 79 years  7,804        2.5  6,767         2.5         787
# 16  2014     .80 to 84 years  5,627        1.8  4,987         1.8         499
# 17  2014  .85 years and over  5,255        1.7  4,684         1.7         454
#
#     Naturalized Pct Not Citizen  Not Citizen Pct
# 15              4.1         250              1.2
# 16              2.6         141              0.7
# 17              2.4         117              0.5

# %%
dftest2.insert(0, 'Year', '2013')
dftest2
# Out:
#     Year                 Age   Total  Total Pct  Native  Native Pct  \
# 0   2013       .0 to 4 years  19,917        6.4  19,686         7.3
# 1   2013       .5 to 9 years  20,536        6.6  20,027         7.4
# 2   2013     .10 to 14 years  20,640        6.6  19,792         7.3
# 3   2013     .15 to 19 years  20,970        6.7  19,512         7.2
# 4   2013     .20 to 24 years  22,153        7.1  19,556         7.2
# 5   2013     .25 to 29 years  21,138        6.8  17,555         6.5
# 6   2013     .30 to 34 years  20,659        6.6  16,510         6.1
# 7   2013     .35 to 39 years  19,221        6.2  14,745         5.4
# 8   2013     .40 to 44 years  20,657        6.6  16,365         6.0
# 9   2013     .45 to 49 years  21,060        6.8  17,015         6.3
# 10  2013     .50 to 54 years  22,386        7.2  18,781         6.9
# 11  2013     .55 to 59 years  20,880        6.7  18,055         6.7
# 12  2013     .60 to 64 years  17,611        5.7  15,334         5.7
# ...

# %%
df_new = pd.concat([dftest, dftest2], axis=0)
df_new
# Out:
#     Year                 Age   Total  Total Pct  Native  Native Pct  \
# 0   2014       .0 to 4 years  19,865        6.3  19,596         7.2
# 1   2014       .5 to 9 years  20,522        6.5  19,914         7.3
# 2   2014     .10 to 14 years  20,642        6.6  19,789         7.3
# 3   2014     .15 to 19 years  20,807        6.6  19,337         7.1
# 4   2014     .20 to 24 years  22,278        7.1  19,981         7.3
# 5   2014     .25 to 29 years  21,474        6.9  18,102         6.6
# 6   2014     .30 to 34 years  20,974        6.7  16,791         6.2
# 7   2014     .35 to 39 years  19,407        6.2  14,947         5.5
# 8   2014     .40 to 44 years  20,382        6.5  15,831         5.8
# 9   2014     .45 to 49 years  20,668        6.6  16,538         6.1
# 10  2014     .50 to 54 years  22,355        7.1  18,663         6.8
# 11  2014     .55 to 59 years  21,109        6.7  18,055         6.6
# 12  2014     .60 to 64 years  18,440        5.9  16,007         5.9
# ...

# %%
df_new['Age'] = [x.replace('.','') for x in df_new['Age']]
df_new['Age'] = [x.replace('years','') for x in df_new['Age']]
df_new['Age']
# Out:
# 0          0 to 4
# 1          5 to 9
# 2        10 to 14
# 3        15 to 19
# 4        20 to 24
# 5        25 to 29
# 6        30 to 34
# 7        35 to 39
# 8        40 to 44
# 9        45 to 49
# 10       50 to 54
# 11       55 to 59
# 12       60 to 64
# 13       65 to 69
# 14       70 to 74
# 15       75 to 79
# 16       80 to 84
# 17    85  and over
# 0          0 to 4
# 1          5 to 9
# 2        10 to 14
# 3        15 to 19
# 4        20 to 24
# 5        25 to 29
# 6        30 to 34
# 7        35 to 39
# 8        40 to 44
# 9        45 to 49
# 10       50 to 54
# 11       55 to 59
# 12       60 to 64
# 13       65 to 69
# 14       70 to 74
# 15       75 to 79
# 16       80 to 84
# 17    85  and over
# Name: Age, dtype: object

# %%
df_new['Total'] = [x.replace(',','') for x in df_new['Total']]
df_new['Total'] = df_new['Total'].astype(int)
df_new['Total']
# Out:
# 0     19865
# 1     20522
# 2     20642
# 3     20807
# 4     22278
# 5     21474
# 6     20974
# 7     19407
# 8     20382
# 9     20668
# 10    22355
# 11    21109
# 12    18440
# 13    14986
# 14    10805
# 15     7804
# 16     5627
# 17     5255
# 0     19917
# 1     20536
# 2     20640
# 3     20970
# 4     22153
# 5     21138
# 6     20659
# 7     19221
# 8     20657
# 9     21060
# 10    22386
# 11    20880
# 12    17611
# 13    14437
# 14    10264
# 15     7598
# 16     5692
# 17     5296
# Name: Total, dtype: int64

# %%
df_new['Native'] = [x.replace(',','') for x in df_new['Native']]
df_new['Native'] = df_new['Native'].astype(int)
df_new['Native']
# Out:
# 0     19596
# 1     19914
# 2     19789
# 3     19337
# 4     19981
# 5     18102
# 6     16791
# 7     14947
# 8     15831
# 9     16538
# 10    18663
# 11    18055
# 12    16007
# 13    13195
# 14     9473
# 15     6767
# 16     4987
# 17     4684
# 0     19686
# 1     20027
# 2     19792
# 3     19512
# 4     19556
# 5     17555
# 6     16510
# 7     14745
# 8     16365
# 9     17015
# 10    18781
# 11    18055
# 12    15334
# 13    12708
# 14     8974
# 15     6605
# 16     5087
# 17     4703
# Name: Native, dtype: int64

# %%
df_new
# Out:
#     Year           Age  Total  Total Pct  Native  Native Pct Naturalized  \
# 0   2014       0 to 4   19865        6.3   19596         7.2          80
# 1   2014       5 to 9   20522        6.5   19914         7.3         189
# 2   2014     10 to 14   20642        6.6   19789         7.3         262
# 3   2014     15 to 19   20807        6.6   19337         7.1         415
# 4   2014     20 to 24   22278        7.1   19981         7.3         584
# 5   2014     25 to 29   21474        6.9   18102         6.6         874
# 6   2014     30 to 34   20974        6.7   16791         6.2       1,277
# 7   2014     35 to 39   19407        6.2   14947         5.5       1,526
# 8   2014     40 to 44   20382        6.5   15831         5.8       2,018
# 9   2014     45 to 49   20668        6.6   16538         6.1       2,219
# 10  2014     50 to 54   22355        7.1   18663         6.8       2,111
# 11  2014     55 to 59   21109        6.7   18055         6.6       1,966
# ...

# %%
fig, ax = plt.subplots()

x = df_new['Year']
y1 = df_new['Native']

ax.plot(x, y1, kind='bar')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-211-622f06a9734d> in <module>()
#       4 y1 = df_new['Native']
#       5
# ----> 6 ax.plot(x, y1, kind='bar')
#
# ~/anaconda/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# ~/anaconda/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1404         kwargs = cbook.normalize_kwargs(kwargs, _alias_map)
#    1405
# -> 1406         for line in self._get_lines(*args, **kwargs):
#    1407             self.add_line(line)
#    1408             lines.append(line)
#
# ...

# %%
df = pd.DataFrame({'a': ['120,00', '42,00', '18,00', '23,00'], 
                'b': ['51,23', '18,45', '28,90', '133,00']})

df['a'] = [x.replace(',', '.') for x in df['a']]

df['a'] = df['a'].astype(float)

# %%
df_new.plot(x="Year", y="Native", kind="bar")

# %%
dfemploy = pd.read_excel('/Users/davidmclaughlin/Documents/Data_Bootcamp/censusemploy2014.xlsx')

# %%
dfemploy
# Out:
#    Sex and employment status  Year  Total  Total Pct  Asia Total  Asia Pct  \
# 0                 Both sexes  2014  25476      100.0        7257     100.0
# 1              Both employed  2014  23833       93.5        6849      94.4
# 2             Both full-time  2014  19942       78.3        5769      79.5
# 3             Both part-time  2014   3891       15.3        1080      14.9
# 4            Both unemployed  2014   1643        6.5         408       5.6
# 5                       Male  2014  14665      100.0        3949     100.0
# 6              Male employed  2014  13827       94.3        3712      94.0
# 7             Male full-time  2014  12403       84.6        3338      84.5
# 8             Male part-time  2014   1424        9.7         374       9.5
# 9            Male unemployed  2014    838        5.7         238       6.0
# 10                    Female  2014  10811      100.0        3308     100.0
# ...

# %%
type(dfemploy)
# Out:
# pandas.core.frame.DataFrame

# %%
dfemploy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45 entries, 0 to 44
# Data columns (total 16 columns):
# Sex and employment status    45 non-null object
# Year                         45 non-null int64
# Total                        45 non-null int64
# Total Pct                    45 non-null float64
# Asia                         45 non-null int64
# Asia Pct                     45 non-null float64
# Europe                       45 non-null int64
# Europe Pct                   45 non-null float64
# Total Lat Am                 45 non-null int64
# Total Lat Am Pct             45 non-null float64
# Mexico                       45 non-null int64
# Mexico Pct                   45 non-null float64
# Other Lat Am                 45 non-null int64
# Other Lat Am Pct             45 non-null float64
# Other Areas                  45 non-null int64
# Other Areas Pct              45 non-null float64
# dtypes: float64(7), int64(8), object(1)
# memory usage: 5.7+ KB

# %%
dfemploy = dfemploy.set_index('Sex and employment status') #need to assign to new df

# %%
dfemploy
# Out:
#                            Year  Total  Total Pct  Asia Total  Asia Pct  \
# Sex and employment status
# Both sexes                 2014  25476      100.0        7257     100.0
# Both employed              2014  23833       93.5        6849      94.4
# Both full-time             2014  19942       78.3        5769      79.5
# Both part-time             2014   3891       15.3        1080      14.9
# Both unemployed            2014   1643        6.5         408       5.6
# Male                       2014  14665      100.0        3949     100.0
# Male employed              2014  13827       94.3        3712      94.0
# Male full-time             2014  12403       84.6        3338      84.5
# Male part-time             2014   1424        9.7         374       9.5
# Male unemployed            2014    838        5.7         238       6.0
# Female                     2014  10811      100.0        3308     100.0
# Female employed            2014  10005       92.5        3138      94.9
# ...

# %%
newemploy = dfemploy.loc[['Male employed', 'Female employed']]
newemploy
# Out:
#                            Total  Total Pct  Asia Total  Asia Pct  \
# Sex and employment status
# Male employed              13827       94.3        3712      94.0
# Female employed            10005       92.5        3138      94.9
#
#                            Europe Total  Europe Pct  Total LatAm  LatAm Pct  \
# Sex and employment status
# Male employed                      1192        95.6         7891       94.5
# Female employed                    1063        94.0         4990       91.0
#
#                            Mexico Total  Mexico Pct  Other LatAm Total  \
# Sex and employment status
# Male employed                      4576        95.0               3315
# Female employed                    2296        90.2               2694
#
#                            Other LatAm Pct  Other Total  Other Pct
# Sex and employment status
# Male employed                         93.7         1033       92.5
# Female employed                       91.8          815       91.5

# %%
slimdf = newemploy[['Asia Total', 'Total LatAm']]
slimdf
# Out:
#                            Asia Total  Total LatAm
# Sex and employment status
# Male employed                    3712         7891
# Female employed                  3138         4990

# %%
slimdf = slimdf.reset_index()
slimdf
# Out:
#    index Sex and employment status  Asia Total  Total LatAm
# 0      0             Male employed        3712         7891
# 1      1           Female employed        3138         4990

# %%
# Setting the positions and width for the bars
pos = list(range(len(slimdf['Asia Total']))) 
width = 0.25 

# Plotting the bars
fig, ax = plt.subplots(figsize=(10,5))

# Create a bar with pre_score data,
# in position pos,
plt.bar(pos, 
        #using df['pre_score'] data,
        slimdf['Asia Total'], 
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#EE3224', 
        # with label the first value in first_name
        label=slimdf['Asia Total'][0]) 

# Create a bar with mid_score data,
# in position pos + some width buffer,
plt.bar([p + width for p in pos], 
        #using df['mid_score'] data,
        slimdf['Total LatAm'],
        # of width
        width, 
        # with alpha 0.5
        alpha=0.5, 
        # with color
        color='#F78F1E', 
        # with label the second value in first_name
        label=slimdf['Total LatAm'][1])  

# Set the y axis label
ax.set_ylabel('Total')

# Set the chart's title
ax.set_title('Region')

# Set the position of the x ticks
ax.set_xticks([p + 1.5 * width for p in pos])

# Set the labels for the x ticks
ax.set_xticklabels(slimdf['Sex and employment status'])

# Setting the x-axis and y-axis limits
plt.xlim(min(pos)-width, max(pos)+width*4)
plt.ylim([0, max(slimdf['Asia Total'] + slimdf['Total LatAm'])])

# Adding the legend and showing the plot
plt.legend(['Asia Total', 'Total LatAm'], loc='upper left')
plt.grid()
plt.show()

# %%
fig, ax = plt.subplots()
slimdf['Asia Total'].plot(ax=ax, kind='barh', alpha=0.5)

# %%
dfemploy['Asia']
# Out:
# 0     7257
# 1     6849
# 2     5769
# 3     1080
# 4      408
# 5     3949
# 6     3712
# 7     3338
# 8      374
# 9      238
# 10    3308
# 11    3138
# 12    2431
# 13     707
# 14     170
# 15    7169
# 16    6757
# 17    5614
# 18    1143
# 19     412
# 20    3849
# 21    3634
# 22    3204
# 23     431
# 24     215
# 25    3320
# 26    3123
# 27    2411
# 28     712
# 29     197
# 30    6975
# 31    6487
# 32    5414
# 33    1073
# 34     489
# 35    3774
# 36    3489
# 37    3100
# 38     388
# 39     286
# 40    3201
# 41    2998
# 42    2314
# 43     684
# 44     203
# Name: Asia, dtype: int64

# %%
dfemploy['Year'].sum()
# Out:
# 90585

# %%
dftest[0:4]
# Out:
#      Age   Total  Total Pct  Native  Native pct Naturalized  Naturalized pct  \
# 0    0-4  19,865        6.3  19,596         7.2          80              0.4
# 1    5-9  20,522        6.5  19,914         7.3         189              1.0
# 2  10-14  20,642        6.6  19,789         7.3         262              1.4
# 3  15-19  20,807        6.6  19,337         7.1         415              2.2
#
#   Not citizen  Not citizen pct
# 0         189              0.9
# 1         418              1.9
# 2         591              2.7
# 3       1,055              4.9

# %%
dfemploy14 = pd.read_excel('/Users/davidmclaughlin/Documents/Data_Bootcamp/censusemploy2014.xlsx')
dfemploy13 = pd.read_excel('/Users/davidmclaughlin/Documents/Data_Bootcamp/censusemploy2013.xlsx')
dfemploy12 = pd.read_excel('/Users/davidmclaughlin/Documents/Data_Bootcamp/censusemploy2012.xlsx')
dfemploy11 = pd.read_excel('/Users/davidmclaughlin/Documents/Data_Bootcamp/censusemploy2011.xlsx')
dfemploy10 = pd.read_excel('/Users/davidmclaughlin/Documents/Data_Bootcamp/censusemploy2010.xlsx')
dfemploy09 = pd.read_excel('/Users/davidmclaughlin/Documents/Data_Bootcamp/censusemploy2009.xlsx')
dfemploy08 = pd.read_excel('/Users/davidmclaughlin/Documents/Data_Bootcamp/censusemploy2008.xlsx')
dfemploy07 = pd.read_excel('/Users/davidmclaughlin/Documents/Data_Bootcamp/censusemploy2007.xlsx')
dfemploy06 = pd.read_excel('/Users/davidmclaughlin/Documents/Data_Bootcamp/censusemploy2006.xlsx')
dfemploy05 = pd.read_excel('/Users/davidmclaughlin/Documents/Data_Bootcamp/censusemploy2005.xlsx')

# %%
dfemploy = pd.concat([dfemploy14, dfemploy13, dfemploy12, dfemploy11, dfemploy10, dfemploy09, dfemploy08, dfemploy07,
                     dfemploy06, dfemploy05], axis=0)

# %%
dfemploy[30:70]
# Out:
#    Sex and employment status  Year    Total  Total Pct  Asia Total  Asia Pct  \
# 0                 Both sexes  2012  25253.0      100.0      6975.0     100.0
# 1              Both employed  2012  23043.0       91.3      6487.0      93.0
# 2             Both full-time  2012  19060.0       75.5      5414.0      77.6
# 3             Both part-time  2012   3983.0       15.8      1073.0      15.4
# 4            Both unemployed  2012   2210.0        8.7       489.0       7.0
# 5                       Male  2012  14593.0      100.0      3774.0     100.0
# 6              Male employed  2012  13345.0       91.5      3489.0      92.4
# 7             Male full-time  2012  11746.0       80.5      3100.0      82.1
# 8             Male part-time  2012   1600.0       11.0       388.0      10.3
# 9            Male unemployed  2012   1247.0        8.5       286.0       7.6
# 10                    Female  2012  10660.0      100.0      3201.0     100.0
# ...

# %%
dfemploy.tail()
# Out:
#    Sex and employment status  Year   Total  Total Pct  Asia Total  Asia Pct  \
# 10                    Female  2005  8494.0      100.0      2529.0     100.0
# 11           Female employed  2005  8058.0       94.9      2437.0      96.4
# 12          Female full-time  2005     NaN        NaN         NaN       NaN
# 13          Female part-time  2005     NaN        NaN         NaN       NaN
# 14         Female unemployed  2005   436.0        5.1        92.0       3.6
#
#     Europe Total  Europe Pct  Total LatAm  LatAm Pct  Mexico Total  \
# 10        1070.0       100.0       4246.0      100.0           NaN
# 11        1027.0        96.0       3978.0       93.7           NaN
# 12           NaN         NaN          NaN        NaN           NaN
# 13           NaN         NaN          NaN        NaN           NaN
# 14          43.0         4.0        268.0        6.3           NaN
#
#     Mexico Pct  Other LatAm Total  Other LatAm Pct  Other Total  Other Pct
# ...

# %%
dfemploy = dfemploy.set_index('Sex and employment status')

# %%
dfemploy.head()
# Out:
#                            Year    Total  Total Pct  Asia Total  Asia Pct  \
# Sex and employment status
# Both sexes                 2014  25476.0      100.0      7257.0     100.0
# Both employed              2014  23833.0       93.5      6849.0      94.4
# Both full-time             2014  19942.0       78.3      5769.0      79.5
# Both part-time             2014   3891.0       15.3      1080.0      14.9
# Both unemployed            2014   1643.0        6.5       408.0       5.6
#
#                            Europe Total  Europe Pct  Total LatAm  LatAm Pct  \
# Sex and employment status
# Both sexes                       2378.0       100.0      13834.0      100.0
# Both employed                    2255.0        94.8      12881.0       93.1
# Both full-time                   1856.0        78.0      10831.0       78.3
# Both part-time                    399.0        16.8       2049.0       14.8
# Both unemployed                   123.0         5.2        953.0        6.9
#
# ...

# %%
maleemploydf = dfemploy.loc[['Male employed']]

# %%
maleemploydf
# Out:
#                            Year    Total  Total Pct  Asia Total  Asia Pct  \
# Sex and employment status
# Male employed              2014  13827.0       94.3      3712.0      94.0
# Male employed              2013  13562.0       92.9      3634.0      94.4
# Male employed              2012  13345.0       91.5      3489.0      92.4
# Male employed              2011  12792.0       90.0      3243.0      92.6
# Male employed              2010  12604.0       89.4      3110.0      92.2
# Male employed              2009  12415.0       89.9      3169.0      92.7
# Male employed              2008  13186.0       93.9      3258.0      96.6
# Male employed              2007  13603.0       95.2      3252.0      96.4
# Male employed              2006  13029.0       95.9      3068.0      96.6
# Male employed              2005  12612.0       95.1      2938.0      96.3
#
#                            Europe Total  Europe Pct  Total LatAm  LatAm Pct  \
# Sex and employment status
# ...

# %%
malecountrydf = maleemploydf[['Year', 'Asia Total', 'Europe Total', 'Total LatAm', 'Mexico Total', 'Other Total']]

# %%
malecountrydf
# Out:
#                            Year  Asia Total  Europe Total  Total LatAm  \
# Sex and employment status
# Male employed              2014      3712.0        1192.0       7891.0
# Male employed              2013      3634.0        1268.0       7693.0
# Male employed              2012      3489.0        1249.0       7661.0
# Male employed              2011      3243.0        1266.0       7462.0
# Male employed              2010      3110.0        1284.0       7401.0
# Male employed              2009      3169.0        1260.0       7156.0
# Male employed              2008      3258.0        1260.0       7783.0
# Male employed              2007      3252.0        1293.0       8170.0
# Male employed              2006      3068.0        1214.0       7738.0
# Male employed              2005      2938.0        1238.0       7414.0
#
#                            Mexico Total  Other Total
# Sex and employment status
# Male employed                    4576.0       1033.0
# ...

# %%
malecountrydf = malecountrydf.reset_index()

# %%
malecountrydf
# Out:
#   Sex and employment status  Year  Asia Total  Europe Total  Total LatAm  \
# 0             Male employed  2014      3712.0        1192.0       7891.0
# 1             Male employed  2013      3634.0        1268.0       7693.0
# 2             Male employed  2012      3489.0        1249.0       7661.0
# 3             Male employed  2011      3243.0        1266.0       7462.0
# 4             Male employed  2010      3110.0        1284.0       7401.0
# 5             Male employed  2009      3169.0        1260.0       7156.0
# 6             Male employed  2008      3258.0        1260.0       7783.0
# 7             Male employed  2007      3252.0        1293.0       8170.0
# 8             Male employed  2006      3068.0        1214.0       7738.0
# 9             Male employed  2005      2938.0        1238.0       7414.0
#
#    Mexico Total  Other Total
# 0        4576.0       1033.0
# 1        4518.0        967.0
# 2        4577.0        947.0
# 3        4403.0        821.0
# ...

# %%
malechartdf = malecountrydf.set_index('Year')

# %%
malechartdf
# Out:
#      Sex and employment status  Asia Total  Europe Total  Total LatAm  \
# Year
# 2014             Male employed      3712.0        1192.0       7891.0
# 2013             Male employed      3634.0        1268.0       7693.0
# 2012             Male employed      3489.0        1249.0       7661.0
# 2011             Male employed      3243.0        1266.0       7462.0
# 2010             Male employed      3110.0        1284.0       7401.0
# 2009             Male employed      3169.0        1260.0       7156.0
# 2008             Male employed      3258.0        1260.0       7783.0
# 2007             Male employed      3252.0        1293.0       8170.0
# 2006             Male employed      3068.0        1214.0       7738.0
# 2005             Male employed      2938.0        1238.0       7414.0
#
#       Mexico Total  Other Total
# Year
# 2014        4576.0       1033.0
# 2013        4518.0        967.0
# 2012        4577.0        947.0
# 2011        4403.0        821.0
# ...

# %%
malechartdf = malechartdf.sort_index(ascending=True, axis=0)

# %%
malechartdf.head()
# Out:
#      Sex and employment status  Asia Total  Europe Total  Total LatAm  \
# Year
# 2005             Male employed      2938.0        1238.0       7414.0
# 2006             Male employed      3068.0        1214.0       7738.0
# 2007             Male employed      3252.0        1293.0       8170.0
# 2008             Male employed      3258.0        1260.0       7783.0
# 2009             Male employed      3169.0        1260.0       7156.0
#
#       Mexico Total  Other Total
# Year
# 2005           NaN       1021.0
# 2006        4721.0       1008.0
# 2007        5025.0        887.0
# 2008        4838.0        886.0
# 2009        4461.0        831.0

# %%
malechartdf.plot()

# %%
malechartdf['Mexico Total'].plot()

# %%
malechartdf[['Asia Total', 'Europe Total', 'Mexico Total', 'Total LatAm']].plot(kind='area')

# %%
fig, ax = plt.subplots()
malechartdf.plot(ax=ax)
ax.set_ylim(ymin=0)
# Out:
# (0, 8538.0499999999993)
